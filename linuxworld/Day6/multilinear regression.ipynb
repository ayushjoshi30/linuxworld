# %%
import tkinter as tk
from tkinter import messagebox
import pyttsx3
import datetime
import webbrowser
import random
import requests
import json
import pytz
import speech_recognition as sr
import matplotlib.pyplot as plt
import pygame
import numpy as np

def voice_assistant():
    # The entire code of your voice assistant here

def display_output(output):
    output.delete(1.0, tk.END)
    output.insert(tk.END, output)

def get_news_command():
    speak("Sure, here are some headlines...")
    output = "News:\n"
    # Add code to fetch news headlines and append them to the 'output' variable
    display_output(output)

def tell_joke_command():
    output = "Joke:\n"
    # Add code to get and display a random joke in the 'output' variable
    display_output(output)

def get_time_command():
    output = "Time:\n"
    # Add code to get the current time and append it to the 'output' variable
    display_output(output)

def draw_flag_command():
    draw_indian_flag()
    output = "Indian flag drawn!\n"
    display_output(output)

def titanic_command():
    titanic()
    # Add code to capture the output of the 'titanic' function and display it in the 'output_text' widget

def volume_command():
    volume()
    output = "Volume Controller activated!\n"
    display_output(output)

def open_youtube_command():
    speak("Opening YouTube...")
    webbrowser.open("https://www.youtube.com")

def open_spotify_command():
    speak("Opening Spotify...")
    webbrowser.open("https://www.spotify.com")

def exit_command():
    root.quit()

# Create the Tkinter window
root = tk.Tk()
root.title("Team 23's Assistant")

# Create a text box to display the output
output_text = tk.Text(root, width=50, height=20, wrap=tk.WORD)
output_text.pack()

# Create the menu bar
menu_bar = tk.Menu(root)

# Create the options for the menu
options_menu = tk.Menu(menu_bar, tearoff=0)
options_menu.add_command(label="Get News", command=get_news_command)
options_menu.add_command(label="Tell Joke", command=tell_joke_command)
options_menu.add_command(label="Get Time", command=get_time_command)
options_menu.add_command(label="Draw Indian Flag", command=draw_flag_command)
options_menu.add_command(label="Titanic Model", command=titanic_command)
options_menu.add_command(label="Volume Controller", command=volume_command)
options_menu.add_separator()
options_menu.add_command(label="Open YouTube", command=open_youtube_command)
options_menu.add_command(label="Open Spotify", command=open_spotify_command)
options_menu.add_separator()
options_menu.add_command(label="Exit", command=exit_command)

# Add the menu to the menu bar
menu_bar.add_cascade(label="Options", menu=options_menu)

# Configure the root window to use the menu bar
root.config(menu=menu_bar)

# Run the voice assistant
voice_assistant()

# Start the Tkinter main loop
root.mainloop()
# Out:
#   Cell In [4], line 18
#     def display_output(output):
#     ^
# IndentationError: expected an indented block after function definition on line 15
