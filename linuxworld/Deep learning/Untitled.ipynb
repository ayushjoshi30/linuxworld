# %%
import pandas as pd

# %%
dataset=pd.read_csv("wine.csv")

# %%
dataset
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
y=dataset["Wine"]

# %%
import seaborn as sns

# %%
sns.scatterplot(data=dataset,x="Wine",y=y)
# Out:
# <AxesSubplot: xlabel='Wine', ylabel='Wine'>

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
y_cat=pd.get_dummies(y)

# %%
y_cat
# Out:
#      1  2  3
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 173  0  0  1
# 174  0  0  1
# 175  0  0  1
# 176  0  0  1
# 177  0  0  1
#
# [178 rows x 3 columns]

# %%
dataset
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
x=dataset.drop("Wine",axis=1)

# %%
x
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      14.23        1.71  2.43  15.6  127     2.80        3.06
# 1      13.20        1.78  2.14  11.2  100     2.65        2.76
# 2      13.16        2.36  2.67  18.6  101     2.80        3.24
# 3      14.37        1.95  2.50  16.8  113     3.85        3.49
# 4      13.24        2.59  2.87  21.0  118     2.80        2.69
# ..       ...         ...   ...   ...  ...      ...         ...
# 173    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# ...

# %%
x.shape
# Out:
# (178, 13)

# %%
from keras.models import Sequential

# %%
model=Sequential()

# %%
from keras.layers import Dense

# %%
model.get_config()
# Out:
# {'name': 'sequential_1', 'layers': []}

# %%
model.add(Dense(units=4,input_shape=(13,),activation="relu",bias_initializer="zeros",kernel_initializer="zeros"))

# %%
model.get_config()
# Out:
# {'name': 'sequential_1',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 13),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'dense_input'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense',
#     'trainable': True,
#     'dtype': 'float32',
#     'batch_input_shape': (None, 13),
#     'units': 4,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 56
#
# ...
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Dense(units=4,activation="relu",bias_initializer="zeros",kernel_initializer="zeros"))

# %%
y_cat
# Out:
#      1  2  3
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 173  0  0  1
# 174  0  0  1
# 175  0  0  1
# 176  0  0  1
# 177  0  0  1
#
# [178 rows x 3 columns]

# %%
model.add(Dense(units=3,activation="softmax",bias_initializer="zeros",kernel_initializer="zeros"))

# %%
model.compile(loss="categorical_crossentropy")

# %%
model.fit(x,y_cat,epochs=20)
# Out:
# Epoch 1/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0912
# Epoch 2/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0909
# Epoch 3/20
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0908
# Epoch 4/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0906
# Epoch 5/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0904
# Epoch 6/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0902
# Epoch 7/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0900
# Epoch 8/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0898
# Epoch 9/20
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0897
# Epoch 10/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0895
# Epoch 11/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0893
# Epoch 12/20
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0891
# Epoch 13/20
# ...
