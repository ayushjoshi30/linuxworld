# %% [markdown]
# # Multilinear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv("50_Startups_dataset.csv")

# %%
dataset
# Out:
#     Unnamed: 0  R&D Spend  Administration  Marketing Spend       State  \
# 0            0  165349.30       136897.90        471784.20    New York
# 1            1  162597.80       151377.69        443898.63  California
# 2            2  153441.61       101145.65        407934.64     Florida
# 3            3  144372.51       118671.95        383199.72    New York
# 4            4  142107.44        91391.87        366168.52     Florida
# 5            5  131877.00        99814.81        362861.46    New York
# 6            6  134615.56       147198.97        127716.92  California
# 7            7  130298.23       145530.16        323876.78     Florida
# 8            8  120542.62       148719.05        311613.39    New York
# 9            9  123334.98       108679.27        304981.72  California
# 10          10  101913.18       110594.21        229161.05     Florida
# 11          11  100672.06        91790.71        249744.65  California
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   R&D Spend        50 non-null     float64
#  2   Administration   50 non-null     float64
#  3   Marketing Spend  50 non-null     float64
#  4   State            50 non-null     object
#  5   Profit           50 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'R&D Spend', 'Administration', 'Marketing Spend', 'State',
#        'Profit'],
#       dtype='object')

# %%
y=dataset['Profit']

# %%
x=dataset[['R&D Spend', 'Administration', 'Marketing Spend']]

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
#we provide states with number coz they have some effect on the profit and in linear regression we can't use strings

# %%
state=dataset['State']

# %%
state
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
#One hot eencoding
final=pd.get_dummies(state,drop_first=True)

# %%
#Dummy variable trap is there as they are dependent on eachother

# %%
final
# Out:
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# ...

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.30       136897.90        471784.20
# 1   162597.80       151377.69        443898.63
# 2   153441.61       101145.65        407934.64
# 3   144372.51       118671.95        383199.72
# 4   142107.44        91391.87        366168.52
# 5   131877.00        99814.81        362861.46
# 6   134615.56       147198.97        127716.92
# 7   130298.23       145530.16        323876.78
# 8   120542.62       148719.05        311613.39
# 9   123334.98       108679.27        304981.72
# 10  101913.18       110594.21        229161.05
# 11  100672.06        91790.71        249744.65
# 12   93863.85       127320.48        249839.54
# 13   91992.49       135495.17        252665.03
# 14  119943.34       156547.52        256513.02
# 15  114523.71       122616.94        261776.33
# 16   78013.21       121597.65        264346.16
# 17   94657.26       145077.68        282574.41
# 18   91749.26       114175.89        294919.67
# ...

# %%
x[["Florida","California"]]=final
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_8720\1911507227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[["Florida","California"]]=final
# C:\Users\ayush\AppData\Local\Temp\ipykernel_8720\1911507227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[["Florida","California"]]=final

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  California
# 0   165349.30       136897.90        471784.20        0           1
# 1   162597.80       151377.69        443898.63        0           0
# 2   153441.61       101145.65        407934.64        1           0
# 3   144372.51       118671.95        383199.72        0           1
# 4   142107.44        91391.87        366168.52        1           0
# 5   131877.00        99814.81        362861.46        0           1
# 6   134615.56       147198.97        127716.92        0           0
# 7   130298.23       145530.16        323876.78        1           0
# 8   120542.62       148719.05        311613.39        0           1
# 9   123334.98       108679.27        304981.72        0           0
# 10  101913.18       110594.21        229161.05        1           0
# 11  100672.06        91790.71        249744.65        0           0
# 12   93863.85       127320.48        249839.54        1           0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.20, random_state=1)

model= LinearRegression()
model.fit(x_train, y_train)
b=model.intercept_
c=model.coef_
print("Intercept=", b,"\nCoefficients=", c)

x_test
y_test_pred=model.predict(x_test)
y_test_pred
# Out:
# Intercept= 49549.72792199075
# Coefficients= [ 7.74342081e-01 -9.44369585e-03  2.89183133e-02  5.82738646e+02
#   2.72794662e+02]
# array([114664.5171587 ,  90593.25531618,  75692.94151576,  70221.98679649,
#        179790.3551487 , 171577.0201852 ,  49753.68752024, 102276.75888937,
#         58649.47795765,  98272.12561132])

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,y_test_pred)
# Out:
# 7698.119817495865
